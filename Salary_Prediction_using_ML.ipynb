# %% [markdown]
# <a href="https://colab.research.google.com/github/kurvevaishu-bit/AI-Based-Paper-Corrector-System/blob/main/Salary_Prediction_using_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv')

# %%
df.isnull()
# Out:
#     Experience Years  Salary
# 0              False   False
# 1              False   False
# 2              False   False
# 3              False   False
# 4              False   False
# 5              False   False
# 6              False   False
# 7              False   False
# 8              False   False
# 9              False   False
# 10             False   False
# 11             False   False
# 12             False   False
# 13             False   False
# 14             False   False
# 15             False   False
# 16             False   False
# 17             False   False
# 18             False   False
# 19             False   False
# 20             False   False
# 21             False   False
# 22             False   False
# 23             False   False
# 24             False   False
# 25             False   False
# 26             False   False
# 27             False   False
# 28             False   False
# 29             False   False
# 30             False   False
# ...

# %%
df.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array(df['Experience Years'])
ypoints=np.array(df['Salary'])
plt.bar(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array(df['Experience Years'])
ypoints=np.array(df['Salary'])
plt.scatter(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array(df['Experience Years'])
ypoints=np.array(df['Salary'])
plt.scatter(xpoints,ypoints)
plt.title('Experience Years vs Salary')
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.show()

# %%
df.shape
# Out:
# (40, 2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=2529)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %%
lr= LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)*100
# Out:
# 95.34676826438887

# %%
year=float(input("Enter your Experience in year:"))
salary=lr.predict([[year]])
print("Your Salary is:",salary)
# Out:
# Enter your Experience in year:0.5
# Your Salary is: [31299.76962724]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x=df[['Experience Years']]
y=df[['Salary']]
plt.figure(figsize=(10,3))
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red')
plt.title('Experience Years vs Salary')
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.show()
